# %%
import pandas as pd 
import numpy as np
import csv
import os.path
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches
import sklearn
import seaborn as sns
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder

# %%
summer2019 = pd.read_csv(r'./Data/2019-summer-match-data.csv', dtype = np.array(np.dtype('int16')))
spring2019 = pd.read_csv(r'./Data/2019-spring-match-data.csv', dtype = np.array(np.dtype('int16')))
summer2018 = pd.read_csv(r'./Data/2018-summer-match-data.csv', dtype = np.array(np.dtype('int16')))
worlds2018 = pd.read_csv(r'./Data/2018-worlds-match-data.csv', dtype = np.array(np.dtype('int16')))
spring2018 = pd.read_csv(r'./Data/2018-spring-match-data.csv', dtype = np.array(np.dtype('int16')))

# %%
summer2019 = summer2019.drop(['split','date','ban1','ban2','ban3','ban4','ban5','gameid','url','doubles','triples','quadras','pentas'], axis=1)
spring2019 = spring2019.drop(['split','date','ban1','ban2','ban3','ban4','ban5','gameid','url','doubles','triples','quadras','pentas'], axis=1)
summer2018 = summer2018.drop(['split','date','ban1','ban2','ban3','ban4','ban5','gameid','url','doubles','triples','quadras','pentas'], axis=1)
worlds2018 = worlds2018.drop(['split','date','ban1','ban2','ban3','ban4','ban5','gameid','url','doubles','triples','quadras','pentas'], axis=1)
spring2018 = spring2018.drop(['split','date','ban1','ban2','ban3','ban4','ban5','gameid','url','doubles','triples','quadras','pentas'], axis=1)

# %%
le = preprocessing.LabelEncoder()

# %%
# Out:
#                                                     url league week game  \
# 0     http://matchhistory.na.leagueoflegends.com/en/...    LCS    1    1
# 1     http://matchhistory.na.leagueoflegends.com/en/...    LCS    1    1
# 2     http://matchhistory.na.leagueoflegends.com/en/...    LCS    1    1
# 3     http://matchhistory.na.leagueoflegends.com/en/...    LCS    1    1
# 4     http://matchhistory.na.leagueoflegends.com/en/...    LCS    1    1
# 5     http://matchhistory.na.leagueoflegends.com/en/...    LCS    1    1
# 6     http://matchhistory.na.leagueoflegends.com/en/...    LCS    1    1
# 7     http://matchhistory.na.leagueoflegends.com/en/...    LCS    1    1
# 8     http://matchhistory.na.leagueoflegends.com/en/...    LCS    1    1
# 9     http://matchhistory.na.leagueoflegends.com/en/...    LCS    1    1
# 12    https://matchhistory.na.leagueoflegends.com/en...    LCS    1    1
# 13    https://matchhistory.na.leagueoflegends.com/en...    LCS    1    1
# ...

# %%
summer2019['playerid'] = summer2019['playerid'].astype(str).astype(int)
summer2019.dropna(subset = ['url'], inplace = True)
#summer2019.loc[(summer2019['playerid'] > '100') or (summer2019['playerid'] == '200')]

# %%
summer2019 = summer2019.loc[(summer2019['playerid'] >= 100) & (summer2019['playerid'] <= 200)]

# %%
summer2019.columns
# Out:
# Index(['url', 'league', 'week', 'game', 'patchno', 'playerid', 'side',
#        'position', 'player', 'team', 'champion', 'gamelength', 'result', 'k',
#        'd', 'a', 'teamkills', 'teamdeaths', 'fb', 'fbassist', 'fbvictim',
#        'fbtime', 'kpm', 'okpm', 'ckpm', 'fd', 'fdtime', 'teamdragkills',
#        'oppdragkills', 'elementals', 'oppelementals', 'firedrakes',
#        'waterdrakes', 'earthdrakes', 'airdrakes', 'elders', 'oppelders',
#        'herald', 'heraldtime', 'ft', 'fttime', 'firstmidouter',
#        'firsttothreetowers', 'teamtowerkills', 'opptowerkills', 'fbaron',
#        'fbarontime', 'teambaronkills', 'oppbaronkills', 'dmgtochamps',
#        'dmgtochampsperminute', 'dmgshare', 'earnedgoldshare', 'wards', 'wpm',
#        'wardshare', 'wardkills', 'wcpm', 'visionwards', 'visionwardbuys',
#        'visiblewardclearrate', 'invisiblewardclearrate', 'totalgold',
#        'earnedgpm', 'goldspent', 'gspd', 'minionkills', 'monsterkills',
# ...

# %%
columns = summer2019.isna().any()

# %%
#enc = OneHotEncoder(handle_unknown='ignore')
#enc.fit(summer2019)

# %%
columns = pd.DataFrame({'col_names':columns.index,'col_value':columns.values})

# %%
columns['col_names'].loc[columns['col_value'] == True]
# Out:
# 45        fbaron
# 46    fbarontime
# Name: col_names, dtype: object

# %%
summer2019.dropna(subset = ['fbaron'], inplace = True)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
summer2019.dropna(subset = ['fbarontime'], inplace = True)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# Out:
# False
