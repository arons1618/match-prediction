# %%
import pandas as pd 
import numpy as np
import csv
import os.path
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches

# %%
matches = pd.read_csv(r'./Data/matchinfo.csv')

# %%
matches
# Out:
#      League  Year  Season    Type blueTeamTag  bResult  rResult redTeamTag  \
# 0     NALCS  2015  Spring  Season         TSM        1        0         C9
# 1     NALCS  2015  Spring  Season         CST        0        1        DIG
# 2     NALCS  2015  Spring  Season         WFX        1        0         GV
# 3     NALCS  2015  Spring  Season         TIP        0        1         TL
# 4     NALCS  2015  Spring  Season         CLG        1        0         T8
# 5     NALCS  2015  Spring  Season         DIG        0        1        TIP
# 6     NALCS  2015  Spring  Season         CST        1        0        WFX
# 7     NALCS  2015  Spring  Season          TL        1        0        CLG
# 8     NALCS  2015  Spring  Season          C9        0        1         GV
# 9     NALCS  2015  Spring  Season          T8        1        0        TSM
# 10    NALCS  2015  Spring  Season          GV        1        0        DIG
# ...

# %%
np.where(matches.applymap(lambda x: x == ''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
matches = matches.dropna()

# %%
#http://matchhistory.na.leagueoflegends.com/en/...
#http://matchhistory.na.leagueoflegends.com/en/...
matches
# Out:
#      League  Year  Season    Type blueTeamTag bResult rResult redTeamTag  \
# 0     NALCS  2015  Spring  Season         TSM       1       0         C9
# 1     NALCS  2015  Spring  Season         CST       0       1        DIG
# 2     NALCS  2015  Spring  Season         WFX       1       0         GV
# 3     NALCS  2015  Spring  Season         TIP       0       1         TL
# 4     NALCS  2015  Spring  Season         CLG       1       0         T8
# 5     NALCS  2015  Spring  Season         DIG       0       1        TIP
# 6     NALCS  2015  Spring  Season         CST       1       0        WFX
# 7     NALCS  2015  Spring  Season          TL       1       0        CLG
# 8     NALCS  2015  Spring  Season          C9       0       1         GV
# 9     NALCS  2015  Spring  Season          T8       1       0        TSM
# 10    NALCS  2015  Spring  Season          GV       1       0        DIG
# 11    NALCS  2015  Spring  Season          T8       1       0        CST
# ...

# %%
listBlue = list(dict.fromkeys(matches['blueTeamTag']))

# %%
listRed = list(dict.fromkeys(matches['redTeamTag']))

# %%
listTeam = list(dict.fromkeys(listBlue + listRed))

# %%
team_name = pd.DataFrame(listTeam)

# %%
kills = pd.read_csv(r'./Data/kills.csv', dtype = np.array(np.dtype('int16')))

# %%
kills
# Out:
#                                                   Address    Team    Time  \
# 0       http://matchhistory.na.leagueoflegends.com/en/...  bKills   10.82
# 1       http://matchhistory.na.leagueoflegends.com/en/...  bKills  16.286
# 2       http://matchhistory.na.leagueoflegends.com/en/...  bKills  18.733
# 3       http://matchhistory.na.leagueoflegends.com/en/...  bKills   18.88
# 4       http://matchhistory.na.leagueoflegends.com/en/...  bKills  27.005
# 5       http://matchhistory.na.leagueoflegends.com/en/...  bKills  27.029
# 6       http://matchhistory.na.leagueoflegends.com/en/...  bKills  27.109
# 7       http://matchhistory.na.leagueoflegends.com/en/...  bKills  28.989
# 8       http://matchhistory.na.leagueoflegends.com/en/...  bKills  29.073
# 9       http://matchhistory.na.leagueoflegends.com/en/...  bKills  30.104
# 10      http://matchhistory.na.leagueoflegends.com/en/...  bKills  32.801
# 11      http://matchhistory.na.leagueoflegends.com/en/...  bKills   32.85
# ...

# %%
gold = pd.read_csv(r'./Data/gold.csv', dtype = np.array(np.dtype('int16')))

# %%
gold
# Out:
#                                                  Address            Type  \
# 0      http://matchhistory.na.leagueoflegends.com/en/...        golddiff
# 1      http://matchhistory.na.leagueoflegends.com/en/...        golddiff
# 2      http://matchhistory.na.leagueoflegends.com/en/...        golddiff
# 3      http://matchhistory.na.leagueoflegends.com/en/...        golddiff
# 4      http://matchhistory.na.leagueoflegends.com/en/...        golddiff
# 5      http://matchhistory.na.leagueoflegends.com/en/...        golddiff
# 6      http://matchhistory.na.leagueoflegends.com/en/...        golddiff
# 7      http://matchhistory.na.leagueoflegends.com/en/...        golddiff
# 8      http://matchhistory.na.leagueoflegends.com/en/...        golddiff
# 9      http://matchhistory.na.leagueoflegends.com/en/...        golddiff
# 10     http://matchhistory.na.leagueoflegends.com/en/...        golddiff
# 11     http://matchhistory.na.leagueoflegends.com/en/...        golddiff
# ...
